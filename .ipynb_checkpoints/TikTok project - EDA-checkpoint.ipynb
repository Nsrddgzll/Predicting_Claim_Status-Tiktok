# %% [markdown]
# # **TikTok Project**

# %% [markdown]
# # **Exploratory data analysis**
#
# In this lab, we will examine data provided and prepare it for analysis. We will also design a professional data visualization that tells a story, and will help data-driven decisions for business needs.
#
# <br/>
#
# **The purpose** of this project is to conduct exploratory data analysis on a provided data set. Our mission is to perform EDA on this data with the aim of learning more about the variables. Of particular interest is information related to what distinguishes claim videos from opinion videos.
#
# **The goal** is to explore the dataset and create visualizations.
# <br/>
# *This activity has 4 parts:*
#
# **Part 1:** Imports, links, and loading
#
# **Part 2:** Data Exploration
# *   Data cleaning
#
#
# **Part 3:** Build visualizations
#
# **Part 4:** Evaluate and share results

# %% [markdown]
# # **Visualize a story in and Python**

# %% [markdown]
# # **PACE stages**

# %% [markdown]
# ## **PACE: Plan**
#
# Consider the questions in your PACE Strategy Document and those below where applicable to craft your response:
# 1. Identify any outliers:
#
#
# *   What methods are best for identifying outliers?
# *   How do you make the decision to keep or exclude outliers from any future models?

# %% [markdown]
# **1**
# * Box plot and histogram are essential plots to identify the outliers.
# * Moreover, using descriptive statistics such as `mean` and `median` functions
#
# **2**
# * There are three way to handle outliers. Keep them as it is, reassign them, romove them from the dataset. Keeping outliers or removing them is a decision that you make based on nature of outliers and assumption of model you are going to build.
#     * We can delete them from dataset if we are sure that outliers are typos or error and dataset will be used in the machine learning model
#     * we can reassign them if we have relatively small dataset or we are going to use dataset in the machine learning model
#     * we can keep them as it is if we are not going to use them in the machine learning model or we have chosen a machine learning model that is resistable to the outliers

# %% [markdown]
# ###  **Imports, links, and loading**
#
# For EDA of the data, we will import the packages that would be most helpful, such as `pandas`, `numpy`, `matplotlib.pyplot`, and `seaborn`.

# %%
# Import packages for data manipulation
import numpy as np
import pandas as pd

# Import packages for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# load the dataset into a dataframe. Read in the data and store it as a dataframe object.

# %%
# Load dataset into dataframe
data = pd.read_csv("tiktok_dataset.csv")

# %% [markdown]
# ## **PACE: Analyze**

# %% [markdown]
# ### **Data exploration and cleaning**

# %% [markdown]
# We will start by discovering, using `.head()`, `.size`, and `.shape`.

# %%
# Display the first few rows of the dataframe
data.head()
# Out:
#    # claim_status    video_id  video_duration_sec  \
# 0  1        claim  7017666017                  59
# 1  2        claim  4014381136                  32
# 2  3        claim  9859838091                  31
# 3  4        claim  1866847991                  25
# 4  5        claim  7105231098                  19
#
#                             video_transcription_text verified_status  \
# 0  someone shared with me that drone deliveries a...    not verified
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# 4  someone shared with me that the number of busi...    not verified
#
#   author_ban_status  video_view_count  video_like_count  video_share_count  \
# 0      under review          343296.0           19425.0              241.0
# 1            active          140877.0           77355.0            19034.0
# ...

# %%
# Get the size of the data
data.size
# Out:
# 232584

# %%
# Get the shape of the data
data.shape
# Out:
# (19382, 12)

# %% [markdown]
# Get basic information about the data, using `.info()`.

# %%
# Get basic information about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19382 entries, 0 to 19381
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19382 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19382 non-null  int64
#  3   video_duration_sec        19382 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19382 non-null  object
#  6   author_ban_status         19382 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.8+ MB

# %% [markdown]
# Generating a table of descriptive statistics, using `.describe()`.

# %%
# Generate a table of descriptive statistics
### YOUR CODE HERE ###
data.describe()
# Out:
#                   #      video_id  video_duration_sec  video_view_count  \
# count  19382.000000  1.938200e+04        19382.000000      19084.000000
# mean    9691.500000  5.627454e+09           32.421732     254708.558688
# std     5595.245794  2.536440e+09           16.229967     322893.280814
# min        1.000000  1.234959e+09            5.000000         20.000000
# 25%     4846.250000  3.430417e+09           18.000000       4942.500000
# 50%     9691.500000  5.618664e+09           32.000000       9954.500000
# 75%    14536.750000  7.843960e+09           47.000000     504327.000000
# max    19382.000000  9.999873e+09           60.000000     999817.000000
#
#        video_like_count  video_share_count  video_download_count  \
# count      19084.000000       19084.000000          19084.000000
# mean       84304.636030       16735.248323           1049.429627
# std       133420.546814       32036.174350           2004.299894
# ...

# %% [markdown]
# ### **Select visualization type(s)**

# %% [markdown]
# ### Data Visualization Types for Exploratory Data Analysis (EDA) of TikTok Dataset
#
# During the exploratory data analysis (EDA) phase of the TikTok dataset, it's crucial to choose effective visualization types to understand and explain the data distribution. Below are the selected visualization types, each serving a specific purpose in uncovering insights from the dataset:
#
# 1. **Line Graph**:
#    - Ideal for illustrating trends over time
#
# 2. **Bar Chart**:
#    - Useful for comparing categorical data, such as the distribution of video content categories  or demographic information of TikTok users.
#
# 3. **Box Plot**:
#    - Valuable for visualizing the distribution of numerical data, including identifying outliers.
#
# 4. **Histogram**:
#    - Specifically designed for showcasing the distribution of a single continuous variable.
#
# 5. **Heat Map**:
#    - Effective in highlighting density or concentration patterns within geographical data.
#
# 6. **Scatter Plot**:
#    - Essential for exploring relationships between two numerical variables
#
# By leveraging these diverse visualization types, we aim to gain comprehensive insights into various aspects of the TikTok dataset, enabling informed decision-making and strategy formulation.

# %% [markdown]
# ## **PACE: Construct**

# %% [markdown]
# ### **Build visualizations**
#
# Following the data assessment, the next step is to plot visualizations to better understand the dataset.
#
# Let's proceed with plotting relevant visualization(s) to gain insights into the TikTok dataset.

# %% [markdown]
# #### **video_duration_sec**
#
# To assess the spread of values within the `video_duration_sec` column, we'll generate a box plot and histogram using seaborn library.

# %%
# define function to add relative percentage of each bar to make it more readable
def add_percent(ax, data, factor = 0):
    """
    Add percentage labels slightly above non-zero bars in a bar chart.

    Parameters:
        ax (matplotlib.axes.Axes): The axis of the bar chart.
        data (list): Data for the bar chart.
        factor (float): The factor by which to raise the label above the bar. Default is 0.
    
    """
    total_count = len(data)
    for i,bar in enumerate(ax.patches):
        height = bar.get_height()
        if height > 0:
            height = height + height*factor
            ax.annotate(f'{(height/total_count)*100:.2f}%',
                   (bar.get_x()+bar.get_width()/2, height),
                   ha = 'center', va = 'bottom',
                   rotation = 45, fontsize = 9)

# %%
# Creating a boxplot and histogram to visualize distribution of `video_duration_sec`
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,4))

# Histogram
sns.histplot(x=data.video_duration_sec, 
             bins = range(4,61,5),  # Defining bins
             ax=ax1)
ax1.set_title('Distribution of Video Durations')
ax1.set_xlabel('Video Duration (seconds)')
ax1.set_ylabel('Frequency')

# Adding percentage to the histogram
add_percent(ax1, data)

# Boxplot
sns.boxplot(x=data.claim_status, y = data.video_duration_sec, ax=ax2)
ax2.set_title('Comparison of Video Durations by Claim Status')
ax2.set_xlabel('Claim Status')
ax2.set_ylabel('Video Duration (seconds)')

plt.show()

# %% [markdown]
# The distribution of `video_duration_sec` appears to be roughly uniform, indicating that videos are spread fairly evenly across different duration ranges. Additionally, there are no outliers present in the data, as videos typically cannot exceed 60 seconds in duration. Video durations are the same for claims and opinions

# %% [markdown]
# #### **video_view_count**
#
# Let's create a box plot to examine the distribution of values within the `video_view_count` column. This will help us understand how views are spread across the videos in our dataset, highlighting any potential outliers and giving us an overview of the range of view counts

# %%
# Create a boxplot to visualize distribution of `video_view_count`
fig, ax = plt.subplots(1,2, figsize=(12,6))

# Boxplot
sns.boxplot(y=data.video_view_count, ax=ax[0])
ax[0].set_title('Distribution of Video View Count')
ax[0].set_xlabel('Video View Count')

# Histogram
sns.histplot(x=data.video_view_count, 
             bins = range(0,1100000,100000),
             hue=data.claim_status, 
             palette='pastel',
             ax=ax[1])
ax[1].set_title('Distribution of Video View Count by Claim Status')
ax[1].set_xlabel('Video View Count (1e6)')
ax[1].set_ylabel('Frequency')

# Adding percentage to the histogram
add_percent(ax[1], data)

# Setting ticks
plt.yticks(range(0, 11000, 1000))
plt.xticks(range(0, 1100000, 100000))

plt.show()

# %% [markdown]
# Creating a histogram of the values in the `video_view_count` column to further explore the distribution of this variable.

# %% [markdown]
# The overall distribution of the variable is skewed to the right, indicating that the majority of videos have lower view counts. There are no outliers present in the data.
#
# Specifically, 52% of videos have view counts between 0 and 50,000. Within this range, 48% of videos are categorized as "opinion". Interestingly, all `opinion` videos have view counts between 0 and 50,000.
#
# On the other hand, videos categorized as `claim` have view counts ranging between 0 and 1 million, suggesting a wider distribution of views compared to "opinion" videos.

# %% [markdown]
# #### **video_like_count**
#
# Create a box plot to examine the spread of values in the `video_like_count` column.

# %%
# Creating a boxplot to visualize distribution of `video_like_count`
plt.figure(figsize=(7,3))
sns.boxplot(x= data.video_like_count)
plt.show()

# %% [markdown]
# Create a histogram of the values in the `video_like_count` column to further explore the distribution of this variable.

# %%
# Create a histogram
### YOUR CODE HERE ###
plt.figure(figsize=(12,5))
ax = sns.histplot(x = data.video_like_count, 
                  bins = range(0,650000,50000),
                 hue = data.claim_status)
add_percent(ax,data)
plt.xticks(range(0, 650000, 20000), rotation = 45)
plt.yticks(range(0,11000,1000))

plt.show()

# %% [markdown]
# **Question:** What do you notice about the distribution of this variable?
#
# Distribution of video count per comments follow the same pattern with video_like_comment with one differences. We got outliers that we need to take closer look. 55 % of videos got likes between 0-50k.

# %% [markdown]
# #### **video_comment_count**
#
# Create a box plot to examine the spread of values in the `video_comment_count` column.

# %%
# Create a boxplot to visualize distribution of `video_comment_count`
### YOUR CODE HERE ###
plt.figure(figsize=(7,3))
sns.boxplot(x=data.video_comment_count)
plt.show()

# %% [markdown]
# Create a histogram of the values in the `video_comment_count` column to further explore the distribution of this variable.

# %%
# Create a histogram
### YOUR CODE HERE ###
plt.figure(figsize=(10,5))
ax = sns.histplot(x=data.video_comment_count, 
                  bins= range(0, 2000, 100), 
                  hue = data.claim_status,
                 multiple='stack')
add_percent(ax,data, factor = 0.02)
plt.xticks(range(0,2000,200), rotation=45)
plt.show()

# %% [markdown]
# **Question:** What do you notice about the distribution of this variable?
#
# Distribution is skewed to the right. Variable contains outliers. More than half of the videos have 50 comments

# %% [markdown]
# #### **video_share_count**
#
# Create a box plot to examine the spread of values in the `video_share_count` column.

# %%
# Create a boxplot to visualize distribution of `video_share_count`
### YOUR CODE HERE ###
plt.figure(figsize=(7,2))
sns.boxplot(x=data.video_share_count)
plt.show()

# %% [markdown]
# *Create* a histogram of the values in the `video_share_count` column to further explore the distribution of this variable.

# %%
# Create a histogram
### YOUR CODE HERE ###
data.video_view_count.hist()
# Out:
# <Axes: >

# %% [markdown]
# **Question:** What do you notice about the distribution of this variable?

# %% [markdown]
# #### **video_download_count**
#
# Create a box plot to examine the spread of values in the `video_download_count` column.

# %%
# Create a boxplot to visualize distribution of `video_download_count`
### YOUR CODE HERE ###
plt.figure(figsize = (7,2))
sns.boxplot(x=data.video_download_count)
plt.show()

# %% [markdown]
# Create a histogram of the values in the `video_download_count` column to further explore the distribution of this variable.

# %%
# Create a histogram
### YOUR CODE HERE ###
plt.figure(figsize=(15,7))
ax = sns.histplot(x=data.video_download_count, 
                  bins = range(0,6000, 250))
add_percent(ax, data)
plt.xticks(range(0,6000, 200))
plt.show()

# %% [markdown]
# **Question:** What do you notice about the distribution of this variable?
#
# distribution of variable follows the same pattern as previos examined variables. Videos that dowloaded up to 200 times made up half of the total videos

# %% [markdown]
# #### **Claim status by verification status**
#
# Now, create a histogram with four bars: one for each combination of claim status and verification status.

# %%
# Create a histogram
### YOUR CODE HERE ###
#plt.figure(figsize=(12,5))
ax = sns.histplot(x = data.claim_status, 
                  y = data.verified_status,
                 hue = data.verified_status,
                 cbar=True)
plt.show()

# %%
ax = sns.histplot(x=data.claim_status,
                 hue = data.verified_status,
                 multiple = 'dodge',
                 shrink=0.9)
add_percent(ax,data)

# %% [markdown]
# **Question:** What do you notice about the number of verified users compared to unverified? And how does that affect their likelihood to post opinions?
#
# **Answer** not verified users make up 95 percent of total users. Verified users gets 43 percent of opinions

# %% [markdown]
# #### **Claim status by author ban status**
#
# The previous course used a `groupby()` statement to examine the count of each claim status for each author ban status. Now, use a histogram to communicate the same information.

# %%
# Create a histogram
### YOUR CODE HERE ###
ax = sns.histplot(x= data.claim_status,
                 hue = data.author_ban_status,
                 multiple='dodge',
                 shrink=0.9,
                 palette='pastel')
add_percent(ax,data)

# %% [markdown]
# **Question:** What do you notice about the number of active authors compared to banned authors for both claims and opinions?
#
# **Answer** 1 % of authors are banned and opinion, 7 percent of authors are banned and claim. 89 % of author status are active. Opinion videos tend to have more active vidoes. Claim videos relatively more banned videos than opinion videos

# %% [markdown]
# #### **Median view counts by ban status**
#
# Create a bar plot with three bars: one for each author ban status. The height of each bar should correspond with the median number of views for all videos with that author ban status.

# %%
def add_count(ax, data):
    for i, val in enumerate(data):
        formatted_val = f'{val:.0f}'#format the value
        ax.text(i, val, formatted_val, ha ='center', va = 'bottom')

# %%
# Create a bar plot
### YOUR CODE HERE ###
median_ban_status = data.groupby('author_ban_status')[['video_view_count']].median().reset_index()
median_ban_status
# Out:
#   author_ban_status  video_view_count
# 0            active            8616.0
# 1            banned          448201.0
# 2      under review          365245.5

# %%
ax = sns.barplot(x = median_ban_status.author_ban_status,
                y = median_ban_status.video_view_count)
add_count(ax,median_ban_status['video_view_count'])

# %% [markdown]
# **Question:** What do you notice about the median view counts for non-active authors compared to that of active authors? Based on that insight, what variable might be a good indicator of claim status?
#
# Median view count of is very high for non active authors comparing to those who are active. Banned variables might be good indicator of claim status

# %%
# Calculate the median view count for claim status.
### YOUR CODE HERE ###
median_claim_satus = data.groupby('claim_status')[['video_view_count']].median().reset_index()
median_claim_satus
# Out:
#   claim_status  video_view_count
# 0        claim          501555.0
# 1      opinion            4953.0

# %%
### YOUR CODE HERE ###
ax = sns.barplot(x = median_claim_satus.claim_status, y = median_claim_satus.video_view_count)
add_count(ax, median_claim_satus.video_view_count)

# %%
data.claim_status.value_counts()
# Out:
# claim      9608
# opinion    9476
# Name: claim_status, dtype: int64

# %% [markdown]
# #### **Total views by claim status**
#
# Create a pie graph that depicts the proportions of total views for claim videos and total views for opinion videos.

# %%
video_view_count = data.groupby('claim_status')[['video_view_count']].count().reset_index()
video_view_count
# Out:
#   claim_status  video_view_count
# 0        claim              9608
# 1      opinion              9476

# %%
# Create a pie graph
### YOUR CODE HERE ###
fig, ax = plt.subplots()
ax.pie(video_view_count.video_view_count, labels=video_view_count.claim_status, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# **Question:** What do you notice about the overall view count for claim status?
#
# **Answer:** Video view counts for claims status is roughly equal. 50.3% is claim, 49.7 % is opinion

# %% [markdown]
# ### **Task 4. Determine outliers**
#
# When building predictive models, the presence of outliers can be problematic. For example, if you were trying to predict the view count of a particular video, videos with extremely high view counts might introduce bias to a model. Also, some outliers might indicate problems with how data was captured or recorded.
#
# The ultimate objective of the TikTok project is to build a model that predicts whether a video is a claim or opinion. The analysis you've performed indicates that a video's engagement level is strongly correlated with its claim status. There's no reason to believe that any of the values in the TikTok data are erroneously captured, and they align with expectation of how social media works: a very small proportion of videos get super high engagement levels. That's the nature of viral content.
#
# Nonetheless, it's good practice to get a sense of just how many of your data points could be considered outliers. The definition of an outlier can change based on the details of your project, and it helps to have domain expertise to decide a threshold. You've learned that a common way to determine outliers in a normal distribution is to calculate the interquartile range (IQR) and set a threshold that is 1.5 * IQR above the 3rd quartile.
#
# In this TikTok dataset, the values for the count variables are not normally distributed. They are heavily skewed to the right. One way of modifying the outlier threshold is by calculating the **median** value for each variable and then adding 1.5 * IQR. This results in a threshold that is, in this case, much lower than it would be if you used the 3rd quartile.
#
# Write a for loop that iterates over the column names of each count variable. For each iteration:
# 1. Calculate the IQR of the column
# 2. Calculate the median of the column
# 3. Calculate the outlier threshold (median + 1.5 * IQR)
# 4. Calculate the numer of videos with a count in that column that exceeds the outlier threshold
# 5. Print "Number of outliers, {column name}: {outlier count}"
#
# ```
# Example:
# Number of outliers, video_view_count: ___
# Number of outliers, video_like_count: ___
# Number of outliers, video_share_count: ___
# Number of outliers, video_download_count: ___
# Number of outliers, video_comment_count: ___
# ```

# %%
### YOUR CODE HERE ###
for i in data.columns:
    if data[i].dtypes == float:
        #print(i)
        q1 = data[i].quantile(0.25)
        q3 = data[i].quantile(0.75)
        median = data[i].median()
        iqr = q3-q1
        outliner_treshold = median + 1.5*iqr
        number_of_outliers = data[i][data[i]> outliner_treshold].count()
        print(f'Number of outliers, {i}: {number_of_outliers}')
# Out:
# Number of outliers, video_view_count: 2343
# Number of outliers, video_like_count: 3468
# Number of outliers, video_share_count: 3732
# Number of outliers, video_download_count: 3733
# Number of outliers, video_comment_count: 3882

# %% [markdown]
# #### **Scatterplot**

# %%
# Create a scatterplot of `video_view_count` versus `video_like_count` according to 'claim_status'
### YOUR CODE HERE ###
plt.figure(figsize =(14,6))
sns.scatterplot(x=data.video_view_count, y= data.video_like_count, hue=data.claim_status)
plt.show()

# %%
# Create a scatterplot of ``video_view_count` versus `video_like_count` for opinions only
### YOUR CODE HERE ###
plt.figure(figsize = (15,6))
opinion_df = data[data['claim_status'] == 'opinion']
sns.scatterplot(x = opinion_df.video_view_count, y = opinion_df.video_like_count)
plt.show()

# %%
plt.figure(figsize = (15,6))
opinion_df = data[data['claim_status'] == 'opinion']
sns.scatterplot(x =opinion_df.video_like_count,  y = opinion_df.video_view_count)

# %% [markdown]
# <img src="images/Execute.png" width="100" height="100" align=left>
#
# ## **PACE: Execute**
#
# Consider the questions in your PACE Strategy Document to reflect on the Execute stage.

# %% [markdown]
# ### **Task 5a. Results and evaluation**
#
# Having built visualizations in Tableau and in Python, what have you learned about the dataset? What other questions have your visualizations uncovered that you should pursue?
#
# ***Pro tip:*** Put yourself in your client's perspective, what would they want to know?
#
# Use the following code cells to pursue any additional EDA. Also use the space to make sure your visualizations are clean, easily understandable, and accessible.
#
# ***Ask yourself:*** Did you consider color, contrast, emphasis, and labeling?

# %% [markdown]
# ==> ENTER YOUR RESPONSE HERE
#
# I have learned that claim videos has more view counts, comments, like and download count.
#
# My other questions are that does
#
# My client would likely want to know ...

# %% [markdown]
# ### **Task 5b. Conclusion**
# *Make it professional and presentable*
#
# You have visualized the data you need to share with the director now. Remember, the goal of a data visualization is for an audience member to glean the information on the chart in mere seconds.
#
# *Questions to ask yourself for reflection:*
# Why is it important to conduct Exploratory Data Analysis? What other visuals could you create?

# %% [markdown]
# EDA is important because ...
#
# ==> Explarotary Data analysis is crucial in data analysis process as is serves to uncover key insights, trends and hidden patterns within dataset, enabeling a deeper understanding of underlying information. Using statistical and visual methods, we can identify outliers and accesing data distribution and recognizing relationship between variables. Moreover, Initial exploration is pivotal for subsequant analyticts decision, hypothesis formulation and model selection. EDA is also helpful to identify missing values and incosistent data, giving a room for data cleaning and preprocessing.
#
# Visualizations helped me understand ..
#
# ==> the shape and distribution of dataset, outliers and relatonship between variables.

# %% [markdown]
# You’ve now completed a professional data visualization according to a business need. Well done! Be sure to save your work as a reference for later work in Tableau.

# %% [markdown]
# **Congratulations!** You've completed this lab. However, you may not notice a green check mark next to this item on Coursera's platform. Please continue your progress regardless of the check mark. Just click on the "save" icon at the top of this notebook to ensure your work has been logged.
